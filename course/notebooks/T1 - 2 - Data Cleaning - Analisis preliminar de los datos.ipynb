# %% [markdown]
# # Resumen de los datos: dimensiones y estructuras

# %%
import pandas as pd
import os

# %%
# defino el fullpath
mainpath = "/Users/Natali/Documents/ciencia datos - course/course/datasets"
filename = "titanic/titanic3.csv"
#fullpath = mainpath + "/" + filename
fullpath = os.path.join(mainpath, filename)

# %%
# si no tengo el csv en la maquina
urldata = "https://raw.githubusercontent.com/joanby/python-ml-course/master/datasets/titanic/titanic3.csv"

# %%
data = pd.read_csv(fullpath)

# %%
data.head(10) # si le paso un parametro a la funcion head me devuelve esa cantidad de lineas
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %%
# obtengo los ultimos datos
data.tail(8) # si le paso un numero me devuelve los ultimos de ese numero
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1301       3         0       Youseff, Mr. Gerious    male  45.5      0      0
# 1302       3         0          Yousif, Mr. Wazli    male   NaN      0      0
# 1303       3         0      Yousseff, Mr. Gerious    male   NaN      0      0
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1301    2628   7.2250   NaN        C  NaN  312.0       NaN
# 1302    2647   7.2250   NaN        C  NaN    NaN       NaN
# 1303    2627  14.4583   NaN        C  NaN    NaN       NaN
# ...

# %%
# obtengo la dimencion del dataset
data.shape
# Out:
# (1309, 14)

# %%
#obtengo las columnas del data set
data.columns.values
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %% [markdown]
# ### Vamos a hacer un resumen de los estadísticos básicos de las variables numéricas.

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
# devuelvo los tipos de datos
data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %% [markdown]
# ## Missing values

# %%
# no podemos dejar valores vacios sin tratar
pd.isnull(data["body"]) # si vuelve true es porq es nulo
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1304    False
# 1305     True
# 1306    False
# 1307     True
# 1308     True
# Name: body, Length: 1309, dtype: bool

# %%
# valores no nulos
pd.notnull(data["body"])
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1304     True
# 1305    False
# 1306     True
# 1307    False
# 1308    False
# Name: body, Length: 1309, dtype: bool

# %%
pd.isnull(data["body"]).values.ravel().sum() ## revel construye un unico array de datos para aplicarle alguna funcion, ej sum
# Out:
# 1188

# %%
pd.notnull(data["body"]).values.ravel().sum()
# Out:
# 121

# %% [markdown]
# Los valores que faltan en un data set pueden venir por dos razones:
# * Extracción de los datos (cuando se extraen datos de una base de datos a nuestro datos, pueden haber incompatibilidades y quedan como nulos, porque no son capaces de incorparar al fichero, se puede corregir este proceso mejorando el proceso de extraccion o haciendo una opteccion de datos mucha mas precisas)
# * Recolección de los datos (en algunos casos no se guardan en la base de datos, ejemplo una encuesta, proque no quieran contestar algunas pregunctas, es decir que ni siquiera se pueda extraer de la base de datos)

# %% [markdown]
# ### Borrados de valors que faltan

# %%
# se pueden borrar filas o columnas

# %%
#borrado de fila
# axis= es el eje horizontal --> fila, axis = 1 elimina la columna
#how que filas tiene que borrar. all --> sera borrada si todas sus columnas contiene sus valores nulos
data.dropna(axis=0, how ='all')
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# how = any ---> eliminar si alguna de las columnas posea un valor nulo
data2 = data
data2.dropna(axis=0, how ='any')
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %% [markdown]
# ### Inferir los datos - COmputo de los valores faltantes

# %%
# consiste en remplazar valores por otro, un promedio, rellenar el valor con cero, ... LA eleccion del mejor metodo depende del contexto

# %%
# rellanar los valores faltantes con cero
data3 = data
data3.fillna(0)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# se puede remplazar los valores faltantes por una palabra
data4 = data
data4.fillna('Desconocido')
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex          age  sibsp  parch  ticket     fare        cabin  \
# ...

# %%
# remplaxar dependiendo de la columna
data5 = data
data5['body'] = data5['body'].fillna(0)
data5['home.dest'] = data5['home.dest'].fillna('Desconocido')
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    0.0
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    0.0
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    0.0
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    0.0
#
#                          home.dest
# ...

# %%
# se puede reemplazar por la media(el promedio, excluyendo los valores q faltan)
pd.isnull(data5['age']).values.ravel().sum()
# Out:
# 263

# %%
# premedio . mean()
data5['age'].fillna(data5['age'].mean())
# Out:
# 0       29.000000
# 1        0.916700
# 2        2.000000
# 3       30.000000
# 4       25.000000
#           ...
# 1304    14.500000
# 1305    29.881135
# 1306    26.500000
# 1307    27.000000
# 1308    29.000000
# Name: age, Length: 1309, dtype: float64

# %%
# se lo puede reeemplazar con el valor mas cerca conocido que encuentre antes del mismo y despues del mismo
# metodo ffill ----> forwardFill: va hacia adelante
data5['age'].fillna(method = 'ffill')
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305    14.5000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
# metodo backfill ----> backFill: va hacia atras
data5['age'].fillna(method = 'backfill')
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305    26.5000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64
